# %% [markdown]
# ### NMR shieldings
# * Input molecule from SMILES,
# * Optimization with MMFF then ab-initio
# * Anisotropic shift calculation

# %%
#####################################
#
# Computing NMR shielding constants
#
######################################
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
from rdkit.Chem import rdDetermineBonds, rdMolTransforms
from rdkit.Chem.Draw import IPythonConsole
from IPython.display import Image, display
import pyscf
import gpu4pyscf
from gpu4pyscf import dft
from gpu4pyscf.properties.shielding import eval_shielding
from pyscf.geomopt.geometric_solver import optimize
from gpu4pyscf.dft import rks
import matplotlib.pyplot as plt
from pathlib import Path
import sys, time, random

### Definitionen für das Script
#smiles = 'CCCC(=S)N(CC)CC'  # Gesuchtes Molekül als SMILES
smiles =r'C1=CC(c2ccccc2)(c2ccccc2)Oc2ccc3c([nH]c4ccccc43)c21'  #das r steht für raw string

#zufällige Job-ID erzeugen
eintrags_id = random.randint(1, 100000000)

jobname = f"id{eintrags_id}"

# Filename vom Jobnamen bilden
xyzin =f"xyz/{jobname}.xyz"
logfile=f"logs/{jobname}_gpu.log"
logfile2=f"logs/{jobname}_nmr_gpu.log"
xyzfile=xyzin   # definiert den Namen des xyz Files, welcher in pySCF verwendet wird
xyzout=f"xyz/{jobname}_opt1.xyz"  # definiert den Ausgabefile für den  Optimierungsschritt
molbild = f"xyz/{jobname}.png"

randomKoords=True #use randowm coordinates in Force Field calculation

def save_molecule_as_xyz(mol, filename):
    """Speichert ein Molekül als XYZ-Datei."""
    with open(filename, 'w') as f:
        num_atoms = mol.GetNumAtoms()
        f.write(f"{num_atoms}\n\n")  # Anzahl der Atome und leerer Kommentar

        for atom in mol.GetAtoms():
            pos = mol.GetConformer().GetAtomPosition(atom.GetIdx())
            symbol = atom.GetSymbol()
            f.write(f"{symbol} {pos.x:.4f} {pos.y:.4f} {pos.z:.4f}\n")

molin = Chem.MolFromSmiles(smiles)

# 3D-Koordinaten generieren
molin = Chem.AddHs(molin)  # Wasserstoffatome hinzufügen
AllChem.EmbedMolecule(molin, useRandomCoords=randomKoords)  

# Optimierung mit Kraftfeld

max_iter=200
mmff_variant="MMFF94"
max_iterations = 40
counter = 0


status = AllChem.MMFFOptimizeMolecule(molin,mmff_variant)

if status == 0 : print("Optimierung mit Kraftfeld erfolgreich")
if status == 1 : print("weitere Optimierungen erforderlich")
if status == -1 : print("Initialisierung fehlgeschlageb")


while status == 1 and counter < max_iterations:
           
        # Beispiel für eine Berechnung, die value verändert
        status =AllChem.MMFFOptimizeMolecule(molin,mmff_variant, max_iter)  # Standardanzahl Iterartionen mit Kraftfeld machen
        if counter == 0 : print("weitere Optimierungen mit Kraftfeld gestartet")
        # Zähler erhöhen
        counter += 1
        if status == 0 : print("weitere Optimierung mit Kraftfeld erfolgreich")

print(f"Anzahl der Durchläufe mit dem Kraftfeld: {counter}")
### Jetzt sollte das Molekül mit dem Kraftfeld optimiert sein

# XYZ-Datei speichern
save_molecule_as_xyz(molin, xyzin)
print(f"XYZ-Datei {xyzin} wurde erfolgreich erstellt.")
# Out:
# Optimierung mit Kraftfeld erfolgreich
# Anzahl der Durchläufe mit dem Kraftfeld: 0
# XYZ-Datei xyz/id12439791.xyz wurde erfolgreich erstellt.

# %%
### ab- initio Geometrieoptimierung
### Molekuel und Berechnungssetup
### hier kann verkürzt werden

mol = pyscf.M(atom=xyzfile, basis='6-31g*', output=logfile)
mf_GPU = rks.RKS(mol, xc='b3lyp').density_fit()
mf_GPU.disp = 'd4'    #original d3bj  für Becke-Johnson dumping, möglich sind: d3bj, d3zero, d3bjm, d3zerom, '3op, d4
mf_GPU.grids.level = 3
mf_GPU.conv_tol = 1e-12   # 1e-10 im Original
mf_GPU.max_cycle = 50   # 50 im Original

# Listen für Energien und Gradienten
energies = []
gradients = []

def callback(envs):
    energies.append(envs['energy'])  # SCF-Gesamtenergie speichern
    gradients.append(envs['gradients'])
    #print(envs)


start_time = time.time()
mol_eq = optimize(mf_GPU, maxsteps=50, callback=callback)  #maxtsep = 20 im Original
print("Optimized coordinate:")
print(mol_eq.atom_coords())
print('geometry optimization took', time.time() - start_time, 's')
print()
# Plotten der SCF-Energien
plt.plot(energies)
plt.title('Energy Convergence during Optimization')
plt.xlabel('Optimization Step')
plt.ylabel('Energy')
plt.grid(True)
plt.show()
# Out:
# geometric-optimize called with the following command line:
# /home/sthomas/.conda/envs/mycuda11neu/lib/python3.12/site-packages/ipykernel_launcher.py -f /home/sthomas/.local/share/jupyter/runtime/kernel-d0e99666-e58b-419e-b49e-9a8335471351.json
#
#                                         ())))))))))))))))/
#                                     ())))))))))))))))))))))))),
#                                 *)))))))))))))))))))))))))))))))))
#                         #,    ()))))))))/                .)))))))))),
#                       #%%%%,  ())))))                        .))))))))*
#                       *%%%%%%,  ))              ..              ,))))))).
#                         *%%%%%%,         ***************/.        .)))))))
#                 #%%/      (%%%%%%,    /*********************.       )))))))
#               .%%%%%%#      *%%%%%%,  *******/,     **********,      .))))))
#                 .%%%%%%/      *%%%%%%,  **              ********      .))))))
#           ##      .%%%%%%/      (%%%%%%,                  ,******      /)))))
#         %%%%%%      .%%%%%%#      *%%%%%%,    ,/////.       ******      ))))))
#       #%      %%      .%%%%%%/      *%%%%%%,  ////////,      *****/     ,)))))
#     #%%  %%%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#   #%%%%.      %%%%%#      /%%%%%%*      #%%%%%%   /////)     ******      ))))),
#     #%%%%##%  %%%#      .%%%%%%/      (%%%%%%,  ///////.     /*****      ))))).
#       ##     %%%      .%%%%%%/      *%%%%%%,  ////////.      *****/     ,)))))
#         #%%%%#      /%%%%%%/      (%%%%%%      /)/)//       ******      ))))))
#           ##      .%%%%%%/      (%%%%%%,                  *******      ))))))
#                 .%%%%%%/      *%%%%%%,  **.             /*******      .))))))
#               *%%%%%%/      (%%%%%%   ********/*..,*/*********       *))))))
#                 #%%/      (%%%%%%,    *********************/        )))))))
#                         *%%%%%%,         ,**************/         ,))))))/
#                       (%%%%%%   ()                              ))))))))
#                       #%%%%,  ())))))                        ,)))))))),
#                         #,    ())))))))))                ,)))))))))).
#                                  ()))))))))))))))))))))))))))))))/
#                                     ())))))))))))))))))))))))).
#                                          ())))))))))))))),
#
# -=#  geomeTRIC started. Version: 1.1  #=-
# Current date and time: 2025-02-14 12:15:04
# #========================================================#
# #|     Arguments passed to driver run_optimizer():      |#
# #========================================================#
# customengine              <pyscf.geomopt.geometric_solver.PySCFEngine object at 0x7f4fdbfae090>
# input                     /tmp/tmp2u3b7cvu/2c7b7d1d-5616-45ba-add5-0feb852697e8
# logIni                    /home/sthomas/.conda/envs/mycuda11neu/lib/python3.12/site-packages/pyscf/geomopt/log.ini
# ----------------------------------------------------------
# Custom engine selected.
# Bonds will be generated from interatomic distances less than 1.20 times sum of covalent radii
# 144 internal coordinates being used (instead of 144 Cartesians)
# Internal coordinate system (atoms numbered from 1):
# Distance 1-2
# Distance 1-29
# Distance 1-30
# Distance 2-3
# Distance 2-31
# Distance 3-4
# Distance 3-10
# Distance 3-16
# Distance 4-5
# Distance 4-9
# Distance 5-6
# Distance 5-32
# Distance 6-7
# Distance 6-33
# Distance 7-8
# Distance 7-34
# Distance 8-9
# Distance 8-35
# Distance 9-36
# Distance 10-11
# Distance 10-15
# Distance 11-12
# Distance 11-37
# Distance 12-13
# Distance 12-38
# Distance 13-14
# Distance 13-39
# Distance 14-15
# Distance 14-40
# Distance 15-41
# Distance 16-17
# Distance 17-18
# Distance 17-29
# Distance 18-19
# Distance 18-42
# Distance 19-20
# Distance 19-43
# Distance 20-21
# Distance 20-28
# Distance 21-22
# Distance 21-29
# Distance 22-23
# Distance 22-44
# Distance 23-24
# Distance 23-28
# Distance 24-25
# Distance 24-45
# Distance 25-26
# Distance 25-46
# Distance 26-27
# Distance 26-47
# Distance 27-28
# Distance 27-48
# Angle 2-1-30
# Angle 29-1-30
# Angle 1-2-31
# Angle 3-2-31
# Angle 2-3-4
# Angle 2-3-10
# Angle 2-3-16
# Angle 4-3-10
# Angle 4-3-16
# Angle 10-3-16
# Angle 3-4-9
# Angle 5-4-9
# Angle 4-5-32
# Angle 6-5-32
# Angle 5-6-33
# Angle 7-6-33
# Angle 6-7-34
# Angle 8-7-34
# Angle 7-8-35
# Angle 9-8-35
# Angle 4-9-36
# Angle 8-9-36
# Angle 3-10-15
# Angle 11-10-15
# Angle 10-11-37
# Angle 12-11-37
# Angle 11-12-38
# Angle 13-12-38
# Angle 12-13-39
# Angle 14-13-39
# Angle 13-14-40
# Angle 15-14-40
# Angle 10-15-41
# Angle 14-15-41
# Angle 3-16-17
# Angle 16-17-29
# Angle 18-17-29
# Angle 17-18-42
# Angle 19-18-42
# Angle 18-19-43
# Angle 20-19-43
# Angle 19-20-28
# Angle 21-20-28
# Angle 20-21-29
# Angle 22-21-29
# Angle 21-22-44
# Angle 23-22-44
# Angle 22-23-28
# Angle 24-23-28
# Angle 23-24-45
# Angle 25-24-45
# Angle 24-25-46
# Angle 26-25-46
# Angle 25-26-47
# Angle 27-26-47
# Angle 26-27-48
# Angle 28-27-48
# Angle 20-28-27
# Angle 23-28-27
# Angle 1-29-21
# Angle 17-29-21
# Out-of-Plane 1-2-29-30
# Out-of-Plane 2-1-3-31
# Out-of-Plane 4-3-5-9
# Out-of-Plane 5-4-6-32
# Out-of-Plane 6-5-7-33
# Out-of-Plane 7-6-8-34
# Out-of-Plane 8-7-9-35
# Out-of-Plane 9-4-8-36
# Out-of-Plane 10-3-11-15
# Out-of-Plane 11-10-12-37
# Out-of-Plane 12-11-13-38
# Out-of-Plane 13-12-14-39
# Out-of-Plane 14-13-15-40
# Out-of-Plane 15-10-14-41
# Out-of-Plane 17-16-18-29
# Out-of-Plane 18-17-19-42
# Out-of-Plane 19-18-20-43
# Out-of-Plane 20-19-21-28
# Out-of-Plane 21-20-22-29
# Out-of-Plane 22-21-23-44
# Out-of-Plane 23-22-24-28
# Out-of-Plane 24-23-25-45
# Out-of-Plane 25-24-26-46
# Out-of-Plane 26-25-27-47
# Out-of-Plane 27-26-28-48
# Out-of-Plane 28-20-23-27
# Out-of-Plane 29-1-17-21
# Dihedral 29-1-2-3
# Dihedral 29-1-2-31
# Dihedral 30-1-2-3
# Dihedral 30-1-2-31
# Dihedral 2-1-29-17
# Dihedral 2-1-29-21
# Dihedral 30-1-29-17
# Dihedral 30-1-29-21
# Dihedral 1-2-3-4
# Dihedral 1-2-3-10
# Dihedral 1-2-3-16
# Dihedral 31-2-3-4
# Dihedral 31-2-3-10
# Dihedral 31-2-3-16
# Dihedral 2-3-4-5
# Dihedral 2-3-4-9
# Dihedral 10-3-4-5
# Dihedral 10-3-4-9
# Dihedral 16-3-4-5
# Dihedral 16-3-4-9
# Dihedral 2-3-10-11
# Dihedral 2-3-10-15
# Dihedral 4-3-10-11
# Dihedral 4-3-10-15
# Dihedral 16-3-10-11
# Dihedral 16-3-10-15
# Dihedral 2-3-16-17
# Dihedral 4-3-16-17
# Dihedral 10-3-16-17
# Dihedral 3-4-5-6
# Dihedral 3-4-5-32
# Dihedral 9-4-5-6
# Dihedral 9-4-5-32
# Dihedral 3-4-9-8
# Dihedral 3-4-9-36
# Dihedral 5-4-9-8
# Dihedral 5-4-9-36
# Dihedral 4-5-6-7
# Dihedral 4-5-6-33
# Dihedral 32-5-6-7
# Dihedral 32-5-6-33
# Dihedral 5-6-7-8
# Dihedral 5-6-7-34
# Dihedral 33-6-7-8
# Dihedral 33-6-7-34
# Dihedral 6-7-8-9
# Dihedral 6-7-8-35
# Dihedral 34-7-8-9
# Dihedral 34-7-8-35
# Dihedral 7-8-9-4
# Dihedral 7-8-9-36
# Dihedral 35-8-9-4
# Dihedral 35-8-9-36
# Dihedral 3-10-11-12
# Dihedral 3-10-11-37
# Dihedral 15-10-11-12
# Dihedral 15-10-11-37
# Dihedral 3-10-15-14
# Dihedral 3-10-15-41
# Dihedral 11-10-15-14
# Dihedral 11-10-15-41
# Dihedral 10-11-12-13
# Dihedral 10-11-12-38
# Dihedral 37-11-12-13
# Dihedral 37-11-12-38
# Dihedral 11-12-13-14
# Dihedral 11-12-13-39
# Dihedral 38-12-13-14
# Dihedral 38-12-13-39
# Dihedral 12-13-14-15
# Dihedral 12-13-14-40
# Dihedral 39-13-14-15
# Dihedral 39-13-14-40
# Dihedral 13-14-15-10
# Dihedral 13-14-15-41
# Dihedral 40-14-15-10
# Dihedral 40-14-15-41
# Dihedral 3-16-17-18
# Dihedral 3-16-17-29
# Dihedral 16-17-18-19
# Dihedral 16-17-18-42
# Dihedral 29-17-18-19
# Dihedral 29-17-18-42
# Dihedral 16-17-29-1
# Dihedral 16-17-29-21
# Dihedral 18-17-29-1
# Dihedral 18-17-29-21
# Dihedral 17-18-19-20
# Dihedral 17-18-19-43
# Dihedral 42-18-19-20
# Dihedral 42-18-19-43
# Dihedral 18-19-20-21
# Dihedral 18-19-20-28
# Dihedral 43-19-20-21
# Dihedral 43-19-20-28
# Dihedral 19-20-21-22
# Dihedral 19-20-21-29
# Dihedral 28-20-21-22
# Dihedral 28-20-21-29
# Dihedral 19-20-28-23
# Dihedral 19-20-28-27
# Dihedral 21-20-28-23
# Dihedral 21-20-28-27
# Dihedral 20-21-22-23
# Dihedral 20-21-22-44
# Dihedral 29-21-22-23
# Dihedral 29-21-22-44
# Dihedral 20-21-29-1
# Dihedral 20-21-29-17
# Dihedral 22-21-29-1
# Dihedral 22-21-29-17
# Dihedral 21-22-23-24
# Dihedral 21-22-23-28
# Dihedral 44-22-23-24
# Dihedral 44-22-23-28
# Dihedral 22-23-24-25
# Dihedral 22-23-24-45
# Dihedral 28-23-24-25
# Dihedral 28-23-24-45
# Dihedral 22-23-28-20
# Dihedral 22-23-28-27
# Dihedral 24-23-28-20
# Dihedral 24-23-28-27
# Dihedral 23-24-25-26
# Dihedral 23-24-25-46
# Dihedral 45-24-25-26
# Dihedral 45-24-25-46
# Dihedral 24-25-26-27
# Dihedral 24-25-26-47
# Dihedral 46-25-26-27
# Dihedral 46-25-26-47
# Dihedral 25-26-27-28
# Dihedral 25-26-27-48
# Dihedral 47-26-27-28
# Dihedral 47-26-27-48
# Dihedral 26-27-28-20
# Dihedral 26-27-28-23
# Dihedral 48-27-28-20
# Dihedral 48-27-28-23
# Translation-X 1-48
# Translation-Y 1-48
# Translation-Z 1-48
# Rotation-A 1-48
# Rotation-B 1-48
# Rotation-C 1-48
# <class 'geometric.internal.Distance'> : 53
# <class 'geometric.internal.Angle'> : 61
# <class 'geometric.internal.OutOfPlane'> : 27
# <class 'geometric.internal.Dihedral'> : 139
# <class 'geometric.internal.TranslationX'> : 1
# <class 'geometric.internal.TranslationY'> : 1
# <class 'geometric.internal.TranslationZ'> : 1
# <class 'geometric.internal.RotationA'> : 1
# <class 'geometric.internal.RotationB'> : 1
# <class 'geometric.internal.RotationC'> : 1
# > ===== Optimization Info: ====
# > Job type: Energy minimization
# > Maximum number of optimization cycles: 300
# > Initial / maximum trust radius (Angstrom): 0.100 / 0.300
# > Convergence Criteria:
# > Will converge when all 5 criteria are reached:
# >  |Delta-E| < 1.00e-06
# >  RMS-Grad  < 3.00e-04
# >  Max-Grad  < 4.50e-04
# >  RMS-Disp  < 1.20e-03
# >  Max-Disp  < 1.80e-03
# > === End Optimization Info ===
# output file: logs/id12439791_gpu.log
# Step    0 : Gradient = 1.137e-02/3.419e-02 (rms/max) Energy = -1170.3848231206
# Hessian Eigenvalues: 2.30000e-02 2.30000e-02 2.30000e-02 ... 4.94076e-01 5.01005e-01 5.66493e-01
# Step    1 : Displace = 9.911e-02/1.505e-01 (rms/max) Trust = 1.000e-01 (=) Grad = 1.166e-02/3.372e-02 (rms/max) E (change) = -1170.3824580356 (+2.365e-03) Quality = -0.189
# Hessian Eigenvalues: 2.26684e-02 2.30000e-02 2.30000e-02 ... 4.98364e-01 5.66032e-01 6.40512e-01
# Step    2 : Displace = 4.777e-02/8.372e-02 (rms/max) Trust = 4.956e-02 (-) Grad = 4.222e-03/1.432e-02 (rms/max) E (change) = -1170.3914735613 (-9.016e-03) Quality = 0.942
# Hessian Eigenvalues: 2.26722e-02 2.29988e-02 2.30000e-02 ... 4.99840e-01 5.66338e-01 7.07404e-01
# Step    3 : Displace = 5.954e-02/1.461e-01 (rms/max) Trust = 7.008e-02 (+) Grad = 3.900e-03/1.357e-02 (rms/max) E (change) = -1170.3916222463 (-1.487e-04) Quality = 0.070
# Hessian Eigenvalues: 2.12024e-02 2.28718e-02 2.30000e-02 ... 5.58073e-01 5.66304e-01 5.82346e-01
# Step    4 : Displace = 2.810e-02/5.605e-02 (rms/max) Trust = 2.977e-02 (-) Grad = 1.182e-03/4.042e-03 (rms/max) E (change) = -1170.3929569059 (-1.335e-03) Quality = 0.838
# Hessian Eigenvalues: 2.11194e-02 2.28736e-02 2.29999e-02 ... 5.26206e-01 5.66053e-01 7.47910e-01
# Step    5 : Displace = 4.213e-02/7.851e-02 (rms/max) Trust = 4.210e-02 (+) Grad = 9.702e-04/2.942e-03 (rms/max) E (change) = -1170.3931725851 (-2.157e-04) Quality = 0.916
# Hessian Eigenvalues: 9.79445e-03 2.28762e-02 2.29856e-02 ... 5.42980e-01 5.67737e-01 7.95788e-01
# Step    6 : Displace = 5.939e-02/1.336e-01 (rms/max) Trust = 5.954e-02 (+) Grad = 1.054e-03/2.514e-03 (rms/max) E (change) = -1170.3933960385 (-2.235e-04) Quality = 0.903
# Hessian Eigenvalues: 4.73811e-03 2.28540e-02 2.29877e-02 ... 5.66354e-01 6.77921e-01 8.32242e-01
# Step    7 : Displace = 8.407e-02/1.788e-01 (rms/max) Trust = 8.420e-02 (+) Grad = 7.247e-04/1.831e-03 (rms/max) E (change) = -1170.3937446578 (-3.486e-04) Quality = 1.148
# Hessian Eigenvalues: 2.34469e-03 2.27610e-02 2.29908e-02 ... 5.66045e-01 6.06844e-01 7.42803e-01
# Step    8 : Displace = 1.177e-01/2.281e-01 (rms/max) Trust = 1.191e-01 (+) Grad = 7.377e-04/1.732e-03 (rms/max) E (change) = -1170.3940065529 (-2.619e-04) Quality = 0.687
# Hessian Eigenvalues: 2.54405e-03 2.25233e-02 2.29517e-02 ... 5.74636e-01 6.21548e-01 7.32234e-01
# Step    9 : Displace = 1.181e-01/2.423e-01 (rms/max) Trust = 1.191e-01 (=) Grad = 6.216e-04/1.603e-03 (rms/max) E (change) = -1170.3940946351 (-8.808e-05) Quality = 0.388
# Hessian Eigenvalues: 4.36381e-03 2.19988e-02 2.29055e-02 ... 5.83245e-01 6.73496e-01 7.35952e-01
# Step   10 : Displace = 2.311e-02/6.287e-02 (rms/max) Trust = 1.191e-01 (=) Grad = 3.867e-04/1.036e-03 (rms/max) E (change) = -1170.3941426195 (-4.798e-05) Quality = 0.797
# Hessian Eigenvalues: 4.09244e-03 1.63257e-02 2.28192e-02 ... 5.75590e-01 7.28407e-01 7.51186e-01
# Step   11 : Displace = 1.808e-02/4.130e-02 (rms/max) Trust = 1.684e-01 (+) Grad = 3.104e-04/9.088e-04 (rms/max) E (change) = -1170.3941606938 (-1.807e-05) Quality = 0.569
# Hessian Eigenvalues: 4.89876e-03 1.29603e-02 2.27529e-02 ... 6.18640e-01 7.32816e-01 7.39924e-01
# Step   12 : Displace = 2.245e-02/4.014e-02 (rms/max) Trust = 1.684e-01 (=) Grad = 1.457e-04/3.757e-04 (rms/max) E (change) = -1170.3941776500 (-1.696e-05) Quality = 1.060
# Hessian Eigenvalues: 3.77586e-03 1.15186e-02 2.21472e-02 ... 5.96046e-01 7.32800e-01 7.42298e-01
# Step   13 : Displace = 2.167e-02/4.471e-02 (rms/max) Trust = 2.382e-01 (+) Grad = 2.723e-04/8.725e-04 (rms/max) E (change) = -1170.3941815945 (-3.944e-06) Quality = 0.345
# Hessian Eigenvalues: 2.84995e-03 8.04878e-03 2.15975e-02 ... 6.40180e-01 7.33031e-01 7.47232e-01
# Step   14 : Displace = 1.447e-02/3.120e-02 (rms/max) Trust = 2.382e-01 (=) Grad = 1.605e-04/4.547e-04 (rms/max) E (change) = -1170.3941957017 (-1.411e-05) Quality = 1.074
# Hessian Eigenvalues: 2.70884e-03 6.20272e-03 2.14296e-02 ... 6.98846e-01 7.33027e-01 7.90522e-01
# Step   15 : Displace = 9.855e-03/3.064e-02 (rms/max) Trust = 3.000e-01 (+) Grad = 1.021e-04/2.249e-04 (rms/max) E (change) = -1170.3942039084 (-8.207e-06) Quality = 1.550
# Hessian Eigenvalues: 2.16263e-03 4.87993e-03 1.91611e-02 ... 6.72689e-01 7.35788e-01 7.44900e-01
# Step   16 : Displace = 1.158e-02/3.658e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.105e-04/3.318e-04 (rms/max) E (change) = -1170.3942081433 (-4.235e-06) Quality = 1.064
# Hessian Eigenvalues: 1.64206e-03 4.61538e-03 1.66017e-02 ... 6.76021e-01 7.35345e-01 7.56148e-01
# Step   17 : Displace = 6.408e-03/1.914e-02 (rms/max) Trust = 3.000e-01 (=) Grad = 1.128e-04/3.960e-04 (rms/max) E (change) = -1170.3942083091 (-1.658e-07) Quality = 0.065
# Hessian Eigenvalues: 1.87888e-03 4.84881e-03 1.48389e-02 ... 7.29419e-01 7.43272e-01 7.59334e-01
# Step   18 : Displace = 3.201e-03/9.253e-03 (rms/max) Trust = 3.204e-03 (-) Grad = 4.568e-05/1.117e-04 (rms/max) E (change) = -1170.3942095403 (-1.231e-06) Quality = 0.844
# Hessian Eigenvalues: 1.85068e-03 4.84856e-03 1.35697e-02 ... 6.93715e-01 7.37838e-01 7.51480e-01
# Step   19 : Displace = 3.753e-03/9.251e-03 (rms/max) Trust = 4.531e-03 (+) Grad = 6.760e-05/1.594e-04 (rms/max) E (change) = -1170.3942093317 (+2.086e-07) Quality = -0.302
# Hessian Eigenvalues: 1.86759e-03 5.00971e-03 1.02194e-02 ... 7.36865e-01 7.39195e-01 8.00011e-01
# Step   20 : Displace = 1.403e-03/3.110e-03 (rms/max) Trust = 1.877e-03 (-) Grad = 2.297e-05/8.847e-05 (rms/max) E (change) = -1170.3942098741 (-5.424e-07) Quality = 0.778
# Hessian Eigenvalues: 1.85611e-03 4.88882e-03 8.35206e-03 ... 7.32891e-01 7.41634e-01 7.49921e-01
# Step   21 : Displace = 1.201e-03/3.694e-03 (rms/max) Trust = 2.654e-03 (+) Grad = 2.490e-05/7.170e-05 (rms/max) E (change) = -1170.3942100505 (-1.764e-07) Quality = 0.656
# Hessian Eigenvalues: 1.58011e-03 3.09374e-03 5.35998e-03 ... 7.36788e-01 7.44189e-01 9.75305e-01
# Step   22 : Displace = 2.655e-03/5.645e-03 (rms/max) Trust = 2.654e-03 (=) Grad = 3.834e-05/1.096e-04 (rms/max) E (change) = -1170.3942101387 (-8.821e-08) Quality = 0.152
# Hessian Eigenvalues: 1.13029e-03 2.24586e-03 5.20117e-03 ... 7.36745e-01 7.44136e-01 1.03893e+00
# Step   23 : Displace = 1.420e-03/4.027e-03 (rms/max) Trust = 1.327e-03 (-) Grad = 3.525e-05/8.913e-05 (rms/max) E (change) = -1170.3942102987 (-1.600e-07) Quality = 0.358
# Hessian Eigenvalues: 8.96717e-04 1.98514e-03 5.02097e-03 ... 7.36821e-01 7.54213e-01 7.70725e-01
# Step   24 : Displace = 1.416e-03/3.573e-03 (rms/max) Trust = 1.327e-03 (=) Grad = 2.784e-05/7.510e-05 (rms/max) E (change) = -1170.3942106057 (-3.070e-07) Quality = 0.504
# Hessian Eigenvalues: 9.70816e-04 2.02408e-03 4.96822e-03 ... 7.36885e-01 7.48985e-01 8.90903e-01
# Step   25 : Displace = 1.367e-03/3.609e-03 (rms/max) Trust = 1.327e-03 (=) Grad = 1.690e-05/3.908e-05 (rms/max) E (change) = -1170.3942105826 (+2.305e-08) Quality = -0.059
# Hessian Eigenvalues: 8.12222e-04 1.92885e-03 4.91551e-03 ... 7.36539e-01 7.48622e-01 7.94064e-01
# Step   26 : Displace = 6.827e-04/1.811e-03 (rms/max) Trust = 6.635e-04 (-) Grad = 1.213e-05/3.549e-05 (rms/max) E (change) = -1170.3942105243 (+5.829e-08) Quality = -0.236
# Hessian Eigenvalues: 7.18490e-04 1.88145e-03 4.44701e-03 ... 7.37077e-01 7.53739e-01 8.89927e-01
# Step   27 : Displace = 3.219e-04/7.010e-04 (rms/max) Trust = 3.318e-04 (-) Grad = 1.350e-05/3.440e-05 (rms/max) E (change) = -1170.3942104856 (+3.874e-08) Quality = -0.142
# Hessian Eigenvalues: 7.18490e-04 1.88145e-03 4.44701e-03 ... 7.37077e-01 7.53739e-01 8.89927e-01
# Converged! =D
#
#     #==========================================================================#
#     #| If this code has benefited your research, please support us by citing: |#
#     #|                                                                        |#
#     #| Wang, L.-P.; Song, C.C. (2016) "Geometry optimization made simple with |#
#     #| translation and rotation coordinates", J. Chem, Phys. 144, 214108.     |#
#     #| http://dx.doi.org/10.1063/1.4952956                                    |#
#     #==========================================================================#
# Time elapsed since start of run_optimizer: 103.275 seconds
# Optimized coordinate:
# [[  1.94220982   2.10779446  -2.78387438]
#  [  0.66774403   4.21956104  -2.20634321]
#  [ -0.67841261   4.41741791   0.31666112]
#  [ -0.64693231   7.16519835   1.19506266]
#  [  1.23496961   8.05130744   2.8205335 ]
#  [  1.29869088  10.59445357   3.51507048]
#  [ -0.49736557  12.27842078   2.57299722]
#  [ -2.3692655   11.40187624   0.9339862 ]
#  [ -2.44661468   8.85823364   0.25421454]
#  [ -3.37540608   3.36137694   0.26856648]
#  [ -4.49735044   2.40678101  -1.91601445]
#  [ -6.95684369   1.44589371  -1.84504902]
#  [ -8.30180236   1.41861655   0.41728566]
#  [ -7.18004185   2.36128637   2.61664416]
#  [ -4.73823132   3.33051027   2.53878557]
#  [  0.71582601   3.00566949   2.21770515]
#  [  1.49164524   0.62844004   1.57355493]
#  [  1.77322413  -1.13629341   3.52578731]
#  [  2.66678371  -3.55121722   2.99811121]
#  [  3.27036208  -4.20504193   0.5093199 ]
#  [  2.98611852  -2.37747014  -1.42764847]
#  [  3.71478864  -3.44877121  -3.69755994]
#  [  4.43828302  -5.94062815  -3.30086405]
#  [  5.28398361  -7.73875059  -5.02975393]
#  [  5.90115355 -10.12574484  -4.10302358]
#  [  5.68262576 -10.69902312  -1.52005528]
#  [  4.83488981  -8.89159666   0.19474517]
#  [  4.19887361  -6.48351876  -0.68582293]
#  [  2.11554491   0.07642511  -0.94763915]
#  [  2.92612247   1.93433261  -4.58080911]
#  [  0.55474726   5.81916763  -3.48280028]
#  [  2.63125787   6.74035713   3.54380049]
#  [  2.76155266  11.25915864   4.793979  ]
#  [ -0.4429701   14.25828261   3.11431072]
#  [ -3.78258922  12.69518492   0.1948462 ]
#  [ -3.92716607   8.17687028  -0.99294791]
#  [ -3.44585542   2.39906499  -3.67551025]
#  [ -7.80986944   0.70853958  -3.56136114]
#  [-10.21127893   0.6657819    0.47527443]
#  [ -8.21539005   2.34171999   4.38988477]
#  [ -3.86013879   4.06513229   4.24118471]
#  [  1.26967788  -0.57242996   5.4304153 ]
#  [  2.87110421  -4.92303243   4.51140965]
#  [  3.55675393  -2.6213075   -5.40394392]
#  [  5.45817015  -7.29926324  -7.02789433]
#  [  6.56485493 -11.56643431  -5.40614112]
#  [  6.18118792 -12.57617394  -0.85677145]
#  [  4.66716678  -9.34652644   2.19012551]]
# geometry optimization took 103.29349875450134 s

# %%
# 
# Die Geometrie sichern
#
print(mol_eq.tostring(format='xyz')) # Das stammt aus dem User Guide

mol_eq.tofile(xyzout, format='xyz')
# Out:
# 48
# XYZ from PySCF
# C           1.02777        1.11540       -1.47316
# C           0.35335        2.23290       -1.16755
# C          -0.35900        2.33760        0.16757
# C          -0.34234        3.79166        0.63240
# C           0.65352        4.26057        1.49256
# C           0.68724        5.60634        1.86010
# C          -0.26319        6.49746        1.36157
# C          -1.25376        6.03361        0.49424
# C          -1.29469        4.68758        0.13452
# C          -1.78619        1.77876        0.14212
# C          -2.37990        1.27361       -1.01391
# C          -3.68140        0.76513       -0.97636
# C          -4.39312        0.75070        0.22082
# C          -3.79951        1.24954        1.38467
# C          -2.50736        1.76243        1.34347
# O           0.37880        1.59053        1.17356
# C           0.78934        0.33256        0.83269
# C           0.93835       -0.60130        1.86577
# C           1.41120       -1.87922        1.58653
# C           1.73060       -2.22521        0.26952
# C           1.58019       -1.25810       -0.75548
# N           1.96578       -1.82501       -1.95666
# C           2.34864       -3.14365       -1.74674
# C           2.79616       -4.09517       -2.66163
# C           3.12276       -5.35831       -2.17123
# C           3.00712       -5.66168       -0.80438
# C           2.55851       -4.70523        0.10305
# C           2.22195       -3.43093       -0.36292
# C           1.11950        0.04044       -0.50147
# H           1.54844        1.02360       -2.42406
# H           0.29356        3.07937       -1.84302
# H           1.39240        3.56684        1.87530
# H           1.46135        5.95809        2.53686
# H          -0.23441        7.54516        1.64802
# H          -2.00166        6.71800        0.10311
# H          -2.07817        4.32701       -0.52545
# H          -1.82347        1.26953       -1.94500
# H          -4.13280        0.37494       -1.88459
# H          -5.40358        0.35232        0.25150
# H          -4.34740        1.23918        2.32303
# H          -2.04270        2.15118        2.24434
# H           0.67188       -0.30292        2.87365
# H           1.51932       -2.60516        2.38734
# H           1.88215       -1.38714       -2.85964
# H           2.88834       -3.86260       -3.71900
# H           3.47397       -6.12069       -2.86081
# H           3.27094       -6.65502       -0.45338
# H           2.46976       -4.94597        1.15896
# '48\nXYZ from PySCF\nC           1.02777        1.11540       -1.47316\nC           0.35335        2.23290       -1.16755\nC          -0.35900        2.33760        0.16757\nC          -0.34234        3.79166        0.63240\nC           0.65352        4.26057        1.49256\nC           0.68724        5.60634        1.86010\nC          -0.26319        6.49746        1.36157\nC          -1.25376        6.03361        0.49424\nC          -1.29469        4.68758        0.13452\nC          -1.78619        1.77876        0.14212\nC          -2.37990        1.27361       -1.01391\nC          -3.68140        0.76513       -0.97636\nC          -4.39312        0.75070        0.22082\nC          -3.79951        1.24954        1.38467\nC          -2.50736        1.76243        1.34347\nO           0.37880        1.59053        1.17356\nC           0.78934        0.33256        0.83269\nC           0.93835       -0.60130        1.86577\nC           1.41120       -1.87922        1.58653\nC           1.73060       -2.22521        0.26952\nC           1.58019       -1.25810       -0.75548\nN           1.96578       -1.82501       -1.95666\nC           2.34864       -3.14365       -1.74674\nC           2.79616       -4.09517       -2.66163\nC           3.12276       -5.35831       -2.17123\nC           3.00712       -5.66168       -0.80438\nC           2.55851       -4.70523        0.10305\nC           2.22195       -3.43093       -0.36292\nC           1.11950        0.04044       -0.50147\nH           1.54844        1.02360       -2.42406\nH           0.29356        3.07937       -1.84302\nH           1.39240        3.56684        1.87530\nH           1.46135        5.95809        2.53686\nH          -0.23441        7.54516        1.64802\nH          -2.00166        6.71800        0.10311\nH          -2.07817        4.32701       -0.52545\nH          -1.82347        1.26953       -1.94500\nH          -4.13280        0.37494       -1.88459\nH          -5.40358        0.35232        0.25150\nH          -4.34740        1.23918        2.32303\nH          -2.04270        2.15118        2.24434\nH           0.67188       -0.30292        2.87365\nH           1.51932       -2.60516        2.38734\nH           1.88215       -1.38714       -2.85964\nH           2.88834       -3.86260       -3.71900\nH           3.47397       -6.12069       -2.86081\nH           3.27094       -6.65502       -0.45338\nH           2.46976       -4.94597        1.15896'

# %%
####################################
#
# Ergebnisansicht des Moleküls
#
####################################


import py3Dmol

# Erstelle ein 3D-Objekt
view = py3Dmol.view(width=800, height=400)

# Lese das XYZ-File
with open(xyzout, 'r') as file:
    xyz_data = file.read()

# Füge die XYZ-Daten zur Ansicht hinzu
view.addModel(xyz_data, 'xyz')

# Setze die Darstellung (z.B. als Kugeln und Stäbe)
view.setStyle({'stick': {}})


# Render die Ansicht
view.zoomTo()
view.show()
# Out:
# <div id="3dmolviewer_17395318080388088"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17395318080388088" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17395318080388088 = null;
# var warn = document.getElementById("3dmolwarning_17395318080388088");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17395318080388088 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17395318080388088"),{backgroundColor:"white"});
# viewer_17395318080388088.zoomTo();
# 	viewer_17395318080388088.addModel("48\nXYZ from PySCF\nC           1.02777        1.11540       -1.47316\nC           0.35335        2.23290       -1.16755\nC          -0.35900        2.33760        0.16757\nC          -0.34234        3.79166        0.63240\nC           0.65352        4.26057        1.49256\nC           0.68724        5.60634        1.86010\nC          -0.26319        6.49746        1.36157\nC          -1.25376        6.03361        0.49424\nC          -1.29469        4.68758        0.13452\nC          -1.78619        1.77876        0.14212\nC          -2.37990        1.27361       -1.01391\nC          -3.68140        0.76513       -0.97636\nC          -4.39312        0.75070        0.22082\nC          -3.79951        1.24954        1.38467\nC          -2.50736        1.76243        1.34347\nO           0.37880        1.59053        1.17356\nC           0.78934        0.33256        0.83269\nC           0.93835       -0.60130        1.86577\nC           1.41120       -1.87922        1.58653\nC           1.73060       -2.22521        0.26952\nC           1.58019       -1.25810       -0.75548\nN           1.96578       -1.82501       -1.95666\nC           2.34864       -3.14365       -1.74674\nC           2.79616       -4.09517       -2.66163\nC           3.12276       -5.35831       -2.17123\nC           3.00712       -5.66168       -0.80438\nC           2.55851       -4.70523        0.10305\nC           2.22195       -3.43093       -0.36292\nC           1.11950        0.04044       -0.50147\nH           1.54844        1.02360       -2.42406\nH           0.29356        3.07937       -1.84302\nH           1.39240        3.56684        1.87530\nH           1.46135        5.95809        2.53686\nH          -0.23441        7.54516        1.64802\nH          -2.00166        6.71800        0.10311\nH          -2.07817        4.32701       -0.52545\nH          -1.82347        1.26953       -1.94500\nH          -4.13280        0.37494       -1.88459\nH          -5.40358        0.35232        0.25150\nH          -4.34740        1.23918        2.32303\nH          -2.04270        2.15118        2.24434\nH           0.67188       -0.30292        2.87365\nH           1.51932       -2.60516        2.38734\nH           1.88215       -1.38714       -2.85964\nH           2.88834       -3.86260       -3.71900\nH           3.47397       -6.12069       -2.86081\nH           3.27094       -6.65502       -0.45338\nH           2.46976       -4.94597        1.15896\n","xyz");
# 	viewer_17395318080388088.setStyle({"stick": {}});
# 	viewer_17395318080388088.zoomTo();
# viewer_17395318080388088.render();
# });
# </script>

# %%
# NMR Berechnung

start_time = time.time()

dateipfad = Path(xyzout)

if dateipfad.exists():
    print("Die Datei existiert.")
else:
    print("Die Datei existiert nicht.")
    sys.exit(1)

mol = pyscf.M(atom=xyzout, basis='6-31g*', output=logfile2)
mf = dft.RKS(mol)
mf.xc = 'b3lyp'
mf.kernel()
tensor = eval_shielding(mf)


abschirmung = tensor[0].get()+tensor[1].get()
end_time = time.time()
print(f'Walltime: {end_time-start_time} Sekunden')
print("Programm kann fortgesetzt werden!")
# Out:
# Die Datei existiert.
# output file: logs/id12439791_nmr_gpu.log
# Walltime: 192.43889904022217 Sekunden
# Programm kann fortgesetzt werden!

# %%
#################################################################################################
#
# Constanten für Verschiebungsberchnung
#
# CSHESHIRE Repository (Tantillo)
#
# Table 1a and 1b
#
# delta = (intercept -sigma)/ - slope
#
# Das Vorzeichen von slope wird gleich in die Definition der Konstanten eingepflegt
#
# TMS shielding aus eigener Berechnung delta = sigma - TMS
#
##################################################################################################

intercept1a = 187.4743
slope1a = 0.9269
intercept1b = 188.4418
slope1b = 0.9449
intercept1c = 188.01
slope1c = 0.9378
tmsshield = 190.2218

h_intercept1a = 32.2884
h_slope1a = 0.9957
h_intercept1b = 32.2109
h_slope1b = 1.0157
h_intercept1c = 32.2448
h_slope1c = 1.004
h_tmsshield = 32.1893

shift = [0] *mol.natm
shift1a = [0] *mol.natm
shift1b= [0] *mol.natm
shift1c= [0] *mol.natm
shifttms= [0] *mol.natm


data = []
for i in range(mol.natm):
    shift[i]= (abschirmung[i,0,0] + abschirmung[i,1,1] + abschirmung[i,2,2])/3
    #print(f"Atom {mol._atom[i][0]} {i} hat eine totale Abschirmung von {shift[i]} .")

    if  mol._atom[i][0] =='C':
        shift1a[i] = (intercept1a-shift[i])/slope1a
        shift1b[i] = (intercept1b-shift[i])/slope1b
        shift1c[i] = (intercept1c-shift[i])/slope1c
        shifttms[i] = tmsshield - shift[i]
        data.append({'Atom': mol._atom[i][0], 'Index': i+1, 'Totale Abschirmung': shift[i], 'table1a': shift1a[i], 'table1b' : shift1b[i], 'table1c' : shift1c[i], 'TMS' : shifttms[i]})
'''
    if  mol._atom[i][0] =='H':
        shift1a[i] = (h_intercept1a-shift[i])/h_slope1a
        shift1b[i] = (h_intercept1b-shift[i])/h_slope1b
        shift1c[i] = (h_intercept1c-shift[i])/h_slope1c
        shifttms[i] = h_tmsshield - shift[i]
        data.append({'Atom': mol._atom[i][0], 'Index': i+1, 'Totale Abschirmung': shift[i], 'table1a': shift1a[i], 'table1b' : shift1b[i], 'table1c' : shift1c[i], 'TMS' : shifttms[i]})
 '''
print("weiter")
# Out:
# weiter

# %%
import pandas as pd
from IPython.display import display, HTML
# Erstelle ein DataFrame
df = pd.DataFrame(data)

# Setze die Spaltenüberschriften
df.columns = ['Atom', 'Index', 'Totale Abschirmung', 'table1a', 'table1b', 'table1c', 'TMS']

# Verwende Styler, um die Schriftgröße zu ändern
styled_df = df.style.set_table_attributes('style="font-size: 17px;"')  # Ändere die Schriftgröße hier

# Zeige die Tabelle an
display(HTML(f"<h2 style=color:#069>{jobname}</h2>"))
display(styled_df)

# Zeige die Tabelle an
# Out:
# <h2 style=color:#069>id12439791</h2>
# <style type="text/css">
# </style>
# <table id="T_7c589" style="font-size: 17px;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c589_level0_col0" class="col_heading level0 col0" >Atom</th>
#       <th id="T_7c589_level0_col1" class="col_heading level0 col1" >Index</th>
#       <th id="T_7c589_level0_col2" class="col_heading level0 col2" >Totale Abschirmung</th>
#       <th id="T_7c589_level0_col3" class="col_heading level0 col3" >table1a</th>
#       <th id="T_7c589_level0_col4" class="col_heading level0 col4" >table1b</th>
#       <th id="T_7c589_level0_col5" class="col_heading level0 col5" >table1c</th>
#       <th id="T_7c589_level0_col6" class="col_heading level0 col6" >TMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c589_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c589_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_7c589_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7c589_row0_col2" class="data row0 col2" >75.349032</td>
#       <td id="T_7c589_row0_col3" class="data row0 col3" >120.968031</td>
#       <td id="T_7c589_row0_col4" class="data row0 col4" >119.687552</td>
#       <td id="T_7c589_row0_col5" class="data row0 col5" >120.133256</td>
#       <td id="T_7c589_row0_col6" class="data row0 col6" >114.872768</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c589_row1_col0" class="data row1 col0" >C</td>
#       <td id="T_7c589_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_7c589_row1_col2" class="data row1 col2" >67.716803</td>
#       <td id="T_7c589_row1_col3" class="data row1 col3" >129.202176</td>
#       <td id="T_7c589_row1_col4" class="data row1 col4" >127.764839</td>
#       <td id="T_7c589_row1_col5" class="data row1 col5" >128.271696</td>
#       <td id="T_7c589_row1_col6" class="data row1 col6" >122.504997</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c589_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_7c589_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_7c589_row2_col2" class="data row2 col2" >107.455751</td>
#       <td id="T_7c589_row2_col3" class="data row2 col3" >86.329214</td>
#       <td id="T_7c589_row2_col4" class="data row2 col4" >85.708592</td>
#       <td id="T_7c589_row2_col5" class="data row2 col5" >85.897045</td>
#       <td id="T_7c589_row2_col6" class="data row2 col6" >82.766049</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c589_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_7c589_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_7c589_row3_col2" class="data row3 col2" >50.328609</td>
#       <td id="T_7c589_row3_col3" class="data row3 col3" >147.961690</td>
#       <td id="T_7c589_row3_col4" class="data row3 col4" >146.166992</td>
#       <td id="T_7c589_row3_col5" class="data row3 col5" >146.813170</td>
#       <td id="T_7c589_row3_col6" class="data row3 col6" >139.893191</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c589_row4_col0" class="data row4 col0" >C</td>
#       <td id="T_7c589_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_7c589_row4_col2" class="data row4 col2" >69.855686</td>
#       <td id="T_7c589_row4_col3" class="data row4 col3" >126.894610</td>
#       <td id="T_7c589_row4_col4" class="data row4 col4" >125.501232</td>
#       <td id="T_7c589_row4_col5" class="data row4 col5" >125.990951</td>
#       <td id="T_7c589_row4_col6" class="data row4 col6" >120.366114</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c589_row5_col0" class="data row5 col0" >C</td>
#       <td id="T_7c589_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_7c589_row5_col2" class="data row5 col2" >69.346651</td>
#       <td id="T_7c589_row5_col3" class="data row5 col3" >127.443790</td>
#       <td id="T_7c589_row5_col4" class="data row5 col4" >126.039951</td>
#       <td id="T_7c589_row5_col5" class="data row5 col5" >126.533748</td>
#       <td id="T_7c589_row5_col6" class="data row5 col6" >120.875149</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c589_row6_col0" class="data row6 col0" >C</td>
#       <td id="T_7c589_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_7c589_row6_col2" class="data row6 col2" >70.545277</td>
#       <td id="T_7c589_row6_col3" class="data row6 col3" >126.150635</td>
#       <td id="T_7c589_row6_col4" class="data row6 col4" >124.771429</td>
#       <td id="T_7c589_row6_col5" class="data row6 col5" >125.255623</td>
#       <td id="T_7c589_row6_col6" class="data row6 col6" >119.676523</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c589_row7_col0" class="data row7 col0" >C</td>
#       <td id="T_7c589_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_7c589_row7_col2" class="data row7 col2" >68.969512</td>
#       <td id="T_7c589_row7_col3" class="data row7 col3" >127.850672</td>
#       <td id="T_7c589_row7_col4" class="data row7 col4" >126.439081</td>
#       <td id="T_7c589_row7_col5" class="data row7 col5" >126.935901</td>
#       <td id="T_7c589_row7_col6" class="data row7 col6" >121.252288</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c589_row8_col0" class="data row8 col0" >C</td>
#       <td id="T_7c589_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_7c589_row8_col2" class="data row8 col2" >69.440219</td>
#       <td id="T_7c589_row8_col3" class="data row8 col3" >127.342843</td>
#       <td id="T_7c589_row8_col4" class="data row8 col4" >125.940926</td>
#       <td id="T_7c589_row8_col5" class="data row8 col5" >126.433974</td>
#       <td id="T_7c589_row8_col6" class="data row8 col6" >120.781581</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c589_row9_col0" class="data row9 col0" >C</td>
#       <td id="T_7c589_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_7c589_row9_col2" class="data row9 col2" >52.237553</td>
#       <td id="T_7c589_row9_col3" class="data row9 col3" >145.902197</td>
#       <td id="T_7c589_row9_col4" class="data row9 col4" >144.146732</td>
#       <td id="T_7c589_row9_col5" class="data row9 col5" >144.777614</td>
#       <td id="T_7c589_row9_col6" class="data row9 col6" >137.984247</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c589_row10_col0" class="data row10 col0" >C</td>
#       <td id="T_7c589_row10_col1" class="data row10 col1" >11</td>
#       <td id="T_7c589_row10_col2" class="data row10 col2" >68.536026</td>
#       <td id="T_7c589_row10_col3" class="data row10 col3" >128.318345</td>
#       <td id="T_7c589_row10_col4" class="data row10 col4" >126.897845</td>
#       <td id="T_7c589_row10_col5" class="data row10 col5" >127.398138</td>
#       <td id="T_7c589_row10_col6" class="data row10 col6" >121.685774</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c589_row11_col0" class="data row11 col0" >C</td>
#       <td id="T_7c589_row11_col1" class="data row11 col1" >12</td>
#       <td id="T_7c589_row11_col2" class="data row11 col2" >70.404226</td>
#       <td id="T_7c589_row11_col3" class="data row11 col3" >126.302809</td>
#       <td id="T_7c589_row11_col4" class="data row11 col4" >124.920705</td>
#       <td id="T_7c589_row11_col5" class="data row11 col5" >125.406029</td>
#       <td id="T_7c589_row11_col6" class="data row11 col6" >119.817574</td>
#     </tr>
#     <tr>
#       <th id="T_7c589_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c589_row12_col0" class="data row12 col0" >C</td>
#       <td id="T_7c589_row12_col1" class

# %%
def show_atom_number(mol, label):
    for atom in mol.GetAtoms():
        atom.SetProp(label, str(atom.GetIdx() + 1))
    return mol

# Molekül aus einer XYZ-Datei lesen

raw_mol = Chem.MolFromXYZFile(xyzout)

if raw_mol is not None:
    mol2 = Chem.Mol(raw_mol)
    Chem.rdDetermineBonds.DetermineBonds(mol2)

    # 2D-Koordinaten berechnen
    AllChem.Compute2DCoords(mol2)

    # Atomnummern anzeigen
    show_atom_number(mol2, 'atomNote')


    ### Wasserstoff aus Molekül löschen
    mol3 = Chem.RemoveHs(mol2)
    # Größe der Moleküldarstellung ändern und Bild speichern
    img = Draw.MolToImage(mol3, size=(800, 400))  # Größe anpassen
    img.save(molbild)  # Bild speichern
    #img.show()  # Bild anzeigen
    display(Image(filename=molbild))
else:
    print("Fehler beim Laden des Moleküls aus der XYZ-Datei.")
